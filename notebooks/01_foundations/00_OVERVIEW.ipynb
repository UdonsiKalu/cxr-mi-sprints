# %% [markdown]
# # FOUNDATIONS — Overview
#
# **Previous:** —
# **Home:** [00_START_HERE](../00_START_HERE.ipynb)
# **Next:** [01_tokens](01_tokens.ipynb)
#
# ## Purpose
#
# See the transformer as tensors: tokens → hidden states → residual stream → attention → MLP → block → logits → hooks → **evolution through depth**.
#
# Do not skip into Observe until residual stream and hooks make sense. Prefer **09 evolution** before treating L20 as special.
#
# ## Notebooks
#
# 1. [01_tokens](01_tokens.ipynb)
# 2. [02_hidden_states](02_hidden_states.ipynb)
# 3. [03_residual_stream](03_residual_stream.ipynb)
# 4. [04_attention](04_attention.ipynb)
# 5. [05_mlp](05_mlp.ipynb)
# 6. [06_transformer_block](06_transformer_block.ipynb)
# 7. [07_logits](07_logits.ipynb)
# 8. [08_hooks](08_hooks.ipynb)
# 9. [09_evolution_through_transformer](09_evolution_through_transformer.ipynb) — L0–L27 magnitude → representation → causation preview
#
# ## Prerequisites
#
# Tensor literacy (`06_python_skills/01_tensors.ipynb`). Markdown ladder: `phase0/`.
#
# ## Status
#
# Executable for tokens→hooks + evolution sweep. Stubs elsewhere as noted in START_HERE.
#
# ## CXR connection
#
# Phase 0 grounding PDF · `scripts/_common.py` encode / residual helpers (read later, do not hide ops yet).
