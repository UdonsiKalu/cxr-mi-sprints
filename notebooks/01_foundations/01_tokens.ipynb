# %% [markdown]
# # Tokens and the last index
#
# **Previous:** [00_START_HERE](../00_START_HERE.ipynb)
# **Home:** [../00_START_HERE.ipynb](../00_START_HERE.ipynb)
# **Next:** [02_hidden_states](02_hidden_states.ipynb)
#
# **Kernel:** `CXR local Qwen (faiss_gpu1)`
# **Status:** executable (calls `scripts/` — same as CLI)
#
# ---
#
# ## 1. Why am I learning this?
#
# The model never sees letters — only token ids.
#
# ## 2. Mental model
#
# Shape `[1, T]` = one note, T tokens. Last token index is `-1`.
#
# ## 3. Clinical question
#
# How many tokens is the FOLFOX teaching note, and which piece is last?
#
# ## 4. Prediction
#
# I expect roughly 10–20 tokens for a short clinical sentence.

# %% [markdown]
# ## 5. Minimal Python — setup + load (run once)

# %%
# Shared bootstrap — run this first in every executable notebook
import sys
from pathlib import Path

# notebooks/_lib regardless of how deep this notebook sits
_here = Path.cwd().resolve()
for _p in [_here, *_here.parents]:
    if (_p / "_lib" / "cxr_boot.py").is_file():
        sys.path.insert(0, str(_p / "_lib"))
        break
    if (_p / "notebooks" / "_lib" / "cxr_boot.py").is_file():
        sys.path.insert(0, str(_p / "notebooks" / "_lib"))
        break
else:
    raise RuntimeError("Cannot find notebooks/_lib/cxr_boot.py — open Jupyter with notebooks/ as root")

import cxr_boot
ctx = cxr_boot.setup(layer=20, max_new=24, load_model=True)
model, tok = ctx["model"], ctx["tok"]
NOTE, LAYER, MAX_NEW = ctx["NOTE"], ctx["LAYER"], ctx["MAX_NEW"]
PROMPT_A, PROMPT_B, PROMPT_TEST = ctx["PROMPT_A"], ctx["PROMPT_B"], ctx["PROMPT_TEST"]
look, intervene, process = ctx["look"], ctx["intervene"], ctx["process"]
print("NOTE:", NOTE)
print("LAYER:", LAYER, "ready")

# %% [markdown]
# ## 6. Run

# %%
ids = tok(NOTE, return_tensors="pt")
pieces = tok.convert_ids_to_tokens(ids["input_ids"][0].tolist())
print("shape:", tuple(ids["input_ids"].shape), "→ (batch, tokens)")
print("n_tokens:", int(ids["input_ids"].shape[1]))
print("pieces:", pieces)
print("last index:", int(ids["input_ids"].shape[1]) - 1, "piece:", pieces[-1])

# %% [markdown]
# ## 7–8. What happened / What did I learn?
#
# _(fill after you run)_
#
# ## 9. Claim boundary
#
# ✓ We know the note’s token count and last index.
#
# ✗ We have not looked inside Qwen yet — no hidden state, no causality.
#
# ## 10. CXR connection
#
# Same first step as `look.py --mode capture` before the hook fires.
#
# ## 11. Questions
#
# ## 12. Revision notes
#
# | Date | Change |
# |------|--------|
# | | |
