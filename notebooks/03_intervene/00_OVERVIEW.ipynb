# %% [markdown]
# # INTERVENE — Overview
#
# **Home:** [00_START_HERE](../00_START_HERE.ipynb)
#
# ## Executable now (from `scripts/intervene.py`)
#
# | Notebook | CLI |
# |----------|-----|
# | [activations/01_steering](activations/01_steering.ipynb) | `steer` |
# | [activations/02_activation_patching](activations/02_activation_patching.ipynb) | `patch` |
# | [activations/03_residual_patching](activations/03_residual_patching.ipynb) | `resid_zero` |
# | [activations/05_logit_bias](activations/05_logit_bias.ipynb) | `logit_bias` |
# | [components/01_mlp_ablation](components/01_mlp_ablation.ipynb) | `mlp_zero` |
# | [components/02_attention_ablation](components/02_attention_ablation.ipynb) | `attn_zero` |
#
# Also: [legacy_intervene](legacy_intervene.ipynb)
#
# Do Observe first. Weights stay frozen.
