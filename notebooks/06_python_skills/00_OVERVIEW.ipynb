# %% [markdown]
# # PYTHON SKILLS — Overview
#
# **Previous:** [00_START_HERE](../00_START_HERE.ipynb)
# **Home:** [00_START_HERE](../00_START_HERE.ipynb)
# **Next:** [01_tensors](01_tensors.ipynb)
#
# ## Purpose
#
# See the ops before wrapping them in `src/cxr_mi/`.
#
# ## Notebooks
#
# 1. [01_tensors](01_tensors.ipynb)
# 2. [02_indexing](02_indexing.ipynb)
# 3. [03_matrix_vector_ops](03_matrix_vector_ops.ipynb)
# 4. [04_pytorch_hooks](04_pytorch_hooks.ipynb)
# 5. [05_numpy](05_numpy.ipynb)
# 6. [06_plotting](06_plotting.ipynb)
# 7. [07_huggingface](07_huggingface.ipynb)
#
# ## Status
#
# Scaffolding stubs.
#
# ## CXR connection
#
# Needed to read `hidden[20][0, -1, :]` without treating it as magic.
