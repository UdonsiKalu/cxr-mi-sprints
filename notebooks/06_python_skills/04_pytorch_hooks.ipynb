# %% [markdown]
# # PyTorch hooks
#
# **Previous:** [03_matrix_vector_ops](03_matrix_vector_ops.ipynb)
# **Home:** [00_START_HERE](../00_START_HERE.ipynb)
# **Next:** [05_numpy](05_numpy.ipynb)
#
# **Status:** stub — not implemented yet (scaffolding first pass)
#
# ---
#
# ## 1. Why am I learning this?
#
# _(plain English — fill in)_
#
# ## 2. Mental model
#
# _(my own explanation)_
#
# ## 3. Clinical question
#
# _(oncology example)_
#
# ## 4. Prediction
#
# _(before running)_
#
# ## 5. Minimal Python
#
# Prefer 5–20 lines. See the operation before wrapping it in `src/cxr_mi/`.
#
# ## 6. Output
#
# _(tensors / plots)_
#
# ## 7. What happened?
#
# ## 8. What did I learn?
#
# ## 9. Claim boundary
#
# ✓
# ✗
#
# ## 10. CXR connection
#
# ## 11. Questions
#
# ## 12. Revision notes
#
# | Date | Change in understanding |
# |------|-------------------------|
# | | |

# %%
# Minimal Python — fill when this lesson is unlocked
# Prefer visible ops: h = hidden[layer][0, -1, :]
