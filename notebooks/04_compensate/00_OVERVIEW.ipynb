# %% [markdown]
# # COMPENSATE — Overview
#
# **Home:** [00_START_HERE](../00_START_HERE.ipynb)
#
# ## Executable now (from `scripts/process.py`)
#
# | Notebook | CLI |
# |----------|-----|
# | [01_prompting](01_prompting.ipynb) | `scaffold` |
# | [02_retrieval](02_retrieval.ipynb) | `retrieve` |
# | [03_structured_output](03_structured_output.ipynb) | `constrain` |
# | [04_tools](04_tools.ipynb) | `tool` |
# | [05_symbolic_rules](05_symbolic_rules.ipynb) | `symbolic` |
# | [06_verifiers](06_verifiers.ipynb) | `verifier` |
# | [07_gate_review](07_gate_review.ipynb) | `gate` |
#
# Also: [legacy_process](legacy_process.ipynb)
#
# Teaching demos only — not Dual G3–G9 / not `ground()`.
