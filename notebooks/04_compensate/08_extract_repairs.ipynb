# %% [markdown]
# # Extract repairs
#
# **Status:** CXR Translate G3–G9 live in the evidence lab — **not** re-implemented here.
#
# Read-only: cite Dual mapping artifacts. Do not modify `ground()` from this notebook.

# %%
print('See case study 03_translate_g3_g9 — no extract-repair CLI in process.py')
