# %% [markdown]
# # Reference suite — Overview
#
# **Home:** [../00_START_HERE.ipynb](../00_START_HERE.ipynb)
# **Run:** [RUN_SUITE.ipynb](RUN_SUITE.ipynb)
# **README:** [README.md](README.md)
#
# ## Purpose
#
# Regression / golden metrics for CXR MI–RepEng experiments. Curriculum notebooks stay pedagogical; this folder locks important cases.
#
# ## Phase 1 IDs
#
# | ID | What |
# |----|------|
# | `E00_2_capture_width` | residual width 3584 |
# | `E00_3_block0_add_check` | L0 add path ≈ 0 |
# | `SWEEP_sep_PROMPT_AB` | max \\|A−B\\| at L27 |
# | `CAUSAL_mlp_zero_candidates` | max \\|Δmargin\\| at L20; same_layer false |
#
# ## Rules
#
# 1. **Add-only** — do not overwrite lesson notebooks to “install” the suite.
# 2. **One model** — Connect to Existing live kernel; suite refuses fresh load.
# 3. Streamlit `:8265` is a **different process** — keep it off while the suite kernel holds VRAM.
