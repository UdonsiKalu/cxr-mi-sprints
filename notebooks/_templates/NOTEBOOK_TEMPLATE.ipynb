# %% [markdown]
# # TITLE
#
# **Previous:** [link]
# **Home:** [00_START_HERE](../00_START_HERE.ipynb)
# **Next:** [link]
#
# ---
#
# ## 1. Why am I learning this?
#
# Plain English.
#
# ## 2. Mental model
#
# My own explanation.
#
# ## 3. Clinical question
#
# Use an oncology example.
#
# ## 4. Prediction
#
# What do I think will happen BEFORE running the code?
#
# ## 5. Minimal Python

# %%
# Prefer 5–20 lines. Show the ops.
# Example (do not run until model is loaded elsewhere):
# h = hidden[20][0, -1, :]
# print(h.shape)

# %% [markdown]
# ## 6. Output
#
# Actual model output / tensors / plot.
#
# ## 7. What happened?
#
# Describe the result.
#
# ## 8. What did I learn?
#
# My interpretation in my own words.
#
# ## 9. Claim boundary
#
# ✓ What this result demonstrates.
#
# ✗ What this result does NOT demonstrate.
#
# ## 10. CXR connection
#
# Where this concept appeared in our actual CXR research.
#
# ## 11. Questions
#
# Things I still do not understand.
#
# ## 12. Revision notes
#
# | Date | Change in understanding |
# |------|-------------------------|
# | | |
#
# ---
#
# ### Insight — YYYY-MM-DD
#
# **Source:** ChatGPT / Cursor / DeepSeek / paper / my observation
#
# **Question:** …
#
# **Canonical explanation:** … (rewrite in your own words)
#
# **Why it matters:** …
#
# **Related experiment:** …
#
# **My understanding:** …
