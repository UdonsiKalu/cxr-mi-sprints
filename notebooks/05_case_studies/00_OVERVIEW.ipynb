# %% [markdown]
# # CASE STUDIES — Overview
#
# **Home:** [00_START_HERE](../00_START_HERE.ipynb)
#
# ## Purpose
#
# Canonize full investigations that combine Observe / Intervene / Compensate on oncology notes.
#
# ## Notebooks
#
# - [01_l24_direction_d](01_l24_direction_d.ipynb)
# - [02_l20_mlp_v](02_l20_mlp_v.ipynb)
# - [03_translate_g3_g9](03_translate_g3_g9.ipynb)
# - [04_full_oncology_investigation](04_full_oncology_investigation.ipynb)
#
# ## Status
#
# Stubs. Fill from frozen Track B / Dual artifacts — do not invent new editors here.
#
# ## CXR connection
#
# L24 `d` · L20 MLP `v` · Translate G3–G9 map · n=108 Dual library (cite lab artifacts).
