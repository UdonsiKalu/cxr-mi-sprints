# %% [markdown]
# # Scratchpad
#
# Deliberately messy. **Nothing here is canonical.**
#
# Use for: temporary code, snippets, quick plots, ideas, incomplete experiments, debugging.
#
# When useful → promote to a concept notebook / `src/cxr_mi/` / research notes / artifacts. Else archive/delete.

# %%
# scratch — delete or promote later
print("scratchpad ready")
