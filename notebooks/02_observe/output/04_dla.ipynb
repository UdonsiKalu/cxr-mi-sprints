# %% [markdown]
# # Direct logit attribution (DLA)
#
# **Home:** [00_START_HERE](../../00_START_HERE.ipynb)
#
# **Status:** not in `look.py` yet — placeholder.
#
# When implemented, this will attribute logit changes to residual writes.
# For now use logit_lens + sites.

# %%
# Placeholder — no DLA helper in scripts/ yet
print('DLA not implemented in look.py — skip for now')
