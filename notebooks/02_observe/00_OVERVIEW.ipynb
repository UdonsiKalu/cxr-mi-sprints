# %% [markdown]
# # OBSERVE — Overview
#
# **Previous:** [09_evolution_through_transformer](../01_foundations/09_evolution_through_transformer.ipynb)
# **Home:** [00_START_HERE](../00_START_HERE.ipynb)
#
# ## Purpose
#
# Read activations and outputs. **Do not write** the forward.
#
# ## Executable now (from `scripts/look.py`)
#
# | Notebook | CLI |
# |----------|-----|
# | [representation/01_capture](representation/01_capture.ipynb) | `--mode capture` |
# | [representation/02_positions](representation/02_positions.ipynb) | `positions` |
# | [representation/03_layer_sweep](representation/03_layer_sweep.ipynb) | `layer_sweep` |
# | [representation/04_difference_vectors](representation/04_difference_vectors.ipynb) | `difference` |
# | [representation/05_cosine_similarity](representation/05_cosine_similarity.ipynb) | (same geometry) |
# | [representation/06_direction_projection](representation/06_direction_projection.ipynb) | (explicit) |
# | [representation/09_sae](representation/09_sae.ipynb) | `sae` |
# | [output/01_logits](output/01_logits.ipynb) | `logits` |
# | [output/02_logit_lens](output/02_logit_lens.ipynb) | `logit_lens` |
# | [output/03_logit_margin](output/03_logit_margin.ipynb) | Yes−No margin |
#
# Also: [legacy_look_observe](legacy_look_observe.ipynb) — all modes in one notebook.
#
# ## Not in look.py yet
#
# PCA, probes, per-head, attention patterns, DLA — stubs only.
#
# ## Run order
#
# 1. Open notebook → kernel **CXR local Qwen (faiss_gpu1)**
# 2. Run setup cell (loads 7B once)
# 3. Run the mode cell
