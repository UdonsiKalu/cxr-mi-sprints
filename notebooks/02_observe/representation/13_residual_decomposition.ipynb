# %% [markdown]
# # Residual decomposition
#
# **Home:** [00_START_HERE](../../00_START_HERE.ipynb)
#
# **Status:** planned — **not** in `scripts/look.py` yet.
#
# Runnable Observe modes that exist today: capture, positions, layer_sweep, difference, sae, logits, logit_lens.
#
# Use [legacy_look_observe](../legacy_look_observe.ipynb) or the numbered notebooks that are marked executable.

# %%
print('Not implemented in look.py yet — see 01_capture … 09_sae / output notebooks')
