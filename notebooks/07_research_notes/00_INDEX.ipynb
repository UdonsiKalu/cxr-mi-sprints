# %% [markdown]
# # Research notes — Index
#
# **Home:** [00_START_HERE](../00_START_HERE.ipynb)
#
# | Notebook | Role |
# |----------|------|
# | [concepts](concepts.ipynb) | Canonical concept notes (Insight format) |
# | [hypotheses](hypotheses.ipynb) | H-001… |
# | [experiment_log](experiment_log.ipynb) | EXP-001… |
# | [open_questions](open_questions.ipynb) | Q-001… |
#
# Chats are temporary. These notebooks are canonical after you rewrite in your own words.
#
#
# **Weekly sprints (GitHub):** [cxr-mi-sprints](https://github.com/UdonsiKalu/cxr-mi-sprints) · [project board](https://github.com/users/UdonsiKalu/projects/2) · local copies in [`../../sprints/`](../../sprints/README.md).
