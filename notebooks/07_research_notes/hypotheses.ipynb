# %% [markdown]
# # Hypotheses
#
# ---
#
# **HYPOTHESIS ID:** H-001
#
# **DATE:**
#
# **QUESTION:**
#
# **HYPOTHESIS:**
#
# **WHY I THINK THIS:**
#
# **TEST:**
#
# **RESULT:**
#
# **STATUS:** OPEN / SUPPORTED / NOT SUPPORTED / CLOSED
