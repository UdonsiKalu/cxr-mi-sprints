# %% [markdown]
# # Concepts
#
# Canonical notes. Prefer the Insight format. Do not paste entire chats.
#
# ---
#
# ### Insight — YYYY-MM-DD
#
# **Source:**
#
# **Question:**
#
# **Canonical explanation:**
#
# **Why it matters:**
#
# **Related experiment:**
#
# **My understanding:**
