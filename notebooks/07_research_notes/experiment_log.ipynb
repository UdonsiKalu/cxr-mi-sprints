# %% [markdown]
# # Experiment log
#
# ---
#
# **EXPERIMENT ID:** EXP-001
#
# **DATE:**
#
# **QUESTION:**
#
# **MODEL:**
#
# **CASES:**
#
# **LAYER / SITE:**
#
# **METHOD:**
#
# **CONTROL:**
#
# **RESULT:**
#
# **INTERPRETATION:**
#
# **CLAIM:**
#
# **ARTIFACT:** `artifacts/experiments/EXP-001.json`
#
# **STATUS:**
