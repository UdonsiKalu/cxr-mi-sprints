# %% [markdown]
# # Open questions
#
# ---
#
# **Q-001**
# What exactly is an MLP write?
# → link when answered: _
#
# **Q-002**
# Why can a representation be decodable but non-causal?
# → _
#
# **Q-003**
# What does an SAE feature represent?
# → _
